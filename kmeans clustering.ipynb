# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('Mall_Customers.csv')

# %%
data
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
data.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
data.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %% [markdown]
# # EDA AND VISIUALIZATION

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
sns.distplot(data['Age'])
plt.xlabel('Count')
plt.ylabel('Age')

plt.subplot(1,3,2)
sns.distplot(data['Annual Income (k$)'])
plt.xlabel('Count')
plt.ylabel('Annunal income')

plt.subplot(1,3,3)
sns.distplot(data['Spending Score (1-100)'])
plt.xlabel('Count')
plt.ylabel('Spending')
# Out:
# C:\Users\Zaveri Infotech\AppData\Local\Temp\ipykernel_14992\372000729.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Age'])
# C:\Users\Zaveri Infotech\AppData\Local\Temp\ipykernel_14992\372000729.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
df=data.groupby('Gender').size()
df.plot(kind='pie',colors=['green','orange'],autopct='%.2f%%',labels=['female','male'],subplots=True)
# Out:
# array([<Axes: >], dtype=object)

# %%
data.hist(figsize=(19,8))
# Out:
# array([[<Axes: title={'center': 'CustomerID'}>,
#         <Axes: title={'center': 'Age'}>],
#        [<Axes: title={'center': 'Annual Income (k$)'}>,
#         <Axes: title={'center': 'Spending Score (1-100)'}>]], dtype=object)

# %%
sns.pairplot(data)

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=data,x='Age')
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
plt.figure(figsize=(23,5))
sns.countplot(data=data,x='Annual Income (k$)')
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='count'>

# %%
plt.figure(figsize=(20,8))
sns.scatterplot(data=data,x='Age',y='Annual Income (k$)',hue='Gender',s=200,)
# Out:
# <Axes: xlabel='Age', ylabel='Annual Income (k$)'>

# %%
plt.figure(figsize=(20,8))
sns.scatterplot(data=data,x='Annual Income (k$)',y='Spending Score (1-100)',hue='Gender',s=200,)
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>

# %%
# kmeans clustering

data.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
x=data.iloc[:,[3,4]].values

# %%
x
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
from sklearn.cluster import KMeans

# %%
k=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i, init='k-means++',random_state=0)
    kmeans.fit(x)
    k.append(kmeans.inertia_)

# %%
plt.plot(range(1,11),k)

# %%
k
# Out:
# [269981.28,
#  185917.1425392852,
#  106348.37306211122,
#  73679.78903948836,
#  44448.4554479337,
#  38858.959975143895,
#  31969.42655023547,
#  29858.483597603947,
#  22209.851608025543,
#  20786.936692059156]

# %%
model=KMeans(n_clusters=5, init='k-means++',random_state=0)

# %%
y_kemsn=model.fit_predict(x)

# %%
plt.figure(1 , figsize = (15 , 8))
plt.scatter(x[y_kemsn == 0, 0], x[y_kemsn == 0, 1], s = 100, c = 'magenta', label = 'Cluster 1') ### Cluster 1
plt.scatter(x[y_kemsn == 1, 0], x[y_kemsn == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')  ## Cluster 2
plt.scatter(x[y_kemsn == 2, 0], x[y_kemsn == 2, 1], s = 100, c = 'cyan', label = 'Cluster 3')  ## Cluster 3
plt.scatter(x[y_kemsn == 3, 0], x[y_kemsn == 3, 1], s = 100, c = 'green', label = 'Cluster 4')  ## Cluster 4
plt.scatter(x[y_kemsn == 4, 0], x[y_kemsn == 4, 1], s = 100, c = 'red', label = 'Cluster 5')   ## Cluster 5
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 200, c = 'black', label = 'Centroids')
plt.title('K Means Clustering Algorithm')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()
